# %%
import torch
import torch.nn as nn
import torch.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.utils.data as data_utils

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data

# %%
df_raw = pd.read_csv('../../Deeplearning_dataset/BostonHousing.csv')

# %%
df_raw
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
X = df_raw.drop('medv', axis=1)
y = df_raw['medv']

# %%
# 학습 데이터와 테스트 데이터를 일정 비율로 나누기
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=2022)

# 학습 데이터
print(f"x_train의 크기: {x_train.shape}")
print(f"y_train의 크기: {y_train.shape}\n")

# 테스트 데이터
print(f"x_test의 크기: {x_test.shape}")
print(f"y_test의 크기: {y_test.shape}")
# Out:
# x_train의 크기: (354, 13)
# y_train의 크기: (354,)
#
# x_test의 크기: (152, 13)
# y_test의 크기: (152,)

# %%
# 학습 데이터 Scaling(scale이 다른 데이터들을 비슷한 scale로 맞춰주기 위하여)
scaler = StandardScaler()
scaler.fit(x_train)

x_train_scale = scaler.transform(x_train)
x_test_scale = scaler.transform(x_test) # train 데이터 기준으로 test 데이터를 scaling

# array => tensor
x_train_tensor = torch.FloatTensor(x_train_scale)
y_train_tensor = torch.FloatTensor(y_train.values)

x_test_tensor = torch.FloatTensor(x_test_scale)
y_test_tensor = torch.FloatTensor(y_test.values)

# %%
# 학습 데이터 배치화 시키기
train_data = data_utils.TensorDataset(x_train_tensor, y_train_tensor)

dataloader = DataLoader(train_data, batch_size=100, shuffle=True,
                       drop_last=False) # 마지막에 남는 54개도 그대로 반환

# 배치화된 데이터 확인
for batch_idx, datas in enumerate(dataloader):
    print(f"batch_index: {batch_idx}")
    print(datas[0].shape)       # x_train
    print(datas[1].shape, '\n') # y_train
# Out:
# batch_index: 0
# torch.Size([100, 13])
# torch.Size([100])
#
# batch_index: 1
# torch.Size([100, 13])
# torch.Size([100])
#
# batch_index: 2
# torch.Size([100, 13])
# torch.Size([100])
#
# batch_index: 3
# torch.Size([54, 13])
# torch.Size([54])

# %% [markdown]
# ## Model

# %%
# parameter 정의
input_size = X.shape[-1]
output_size = 1
learning_rate = 0.01
num_epochs = 50

# %%
# model 생성
model = nn.Linear(in_features=input_size, out_features=output_size)

# %%
# 손실함수 정의
criterion = nn.MSELoss()
# Optimizer 정의
optimizer = torch.optim.SGD(params=model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training

# %%
train_loss = []
test_loss = []

for epoch in range(num_epochs):
    
    for idx, (x_batch, y_batch) in enumerate(dataloader):
        # Batch 학습
        model.train()
        optimizer.zero_grad() # gradient 초기화
        
        y_pred = model(x_batch).reshape(-1) # 예측값
        loss_train = criterion(y_pred, y_batch) # loss
        
        loss_train.backward() # graident 계산
        optimizer.step() # weight 업데이트
        
    # Validation
    model.eval()
        
    y_test_pred = model(x_test_tensor).data.reshape(-1)
    loss_test = criterion(y_test_pred, y_test_tensor)
    
    # epoch 마다 train, test loss 저장
    train_loss.append(loss_train.item())
    test_loss.append(loss_test.item())
    
    print(f"epoch: [{epoch+1}] Loss_train: {loss_train:.2f}, Loss_test: {loss_test:.2f}")
# Out:
# epoch: [1] Loss_train: 554.57, Loss_test: 452.23
# epoch: [2] Loss_train: 464.73, Loss_test: 386.81
# epoch: [3] Loss_train: 417.00, Loss_test: 332.17
# epoch: [4] Loss_train: 353.98, Loss_test: 286.37
# epoch: [5] Loss_train: 237.62, Loss_test: 247.11
# epoch: [6] Loss_train: 285.87, Loss_test: 212.79
# epoch: [7] Loss_train: 227.26, Loss_test: 184.02
# epoch: [8] Loss_train: 185.80, Loss_test: 159.23
# epoch: [9] Loss_train: 168.42, Loss_test: 138.43
# epoch: [10] Loss_train: 157.11, Loss_test: 120.48
# epoch: [11] Loss_train: 84.60, Loss_test: 106.00
# epoch: [12] Loss_train: 79.02, Loss_test: 93.25
# epoch: [13] Loss_train: 99.54, Loss_test: 82.18
# epoch: [14] Loss_train: 103.61, Loss_test: 72.89
# epoch: [15] Loss_train: 102.93, Loss_test: 65.17
# epoch: [16] Loss_train: 41.09, Loss_test: 58.75
# epoch: [17] Loss_train: 44.69, Loss_test: 53.21
# epoch: [18] Loss_train: 42.48, Loss_test: 48.88
# epoch: [19] Loss_train: 109.63, Loss_test: 44.64
# epoch: [20] Loss_train: 62.59, Loss_test: 41.39
# epoch: [21] Loss_train: 25.54, Loss_test: 38.67
# epoch: [22] Loss_train: 53.00, Loss_test: 36.20
# epoch: [23] Loss_train: 60.35, Loss_test: 34.13
# epoch: [24] Loss_train: 19.85, Loss_test: 32.50
# epoch: [25] Loss_train: 21.27, Loss_test: 31.10
# epoch: [26] Loss_train: 40.52, Loss_test: 29.85
# epoch: [27] Loss_train: 9.90, Loss_test: 28.85
# epoch: [28] Loss_train: 16.91, Loss_test: 28.02
# epoch: [29] Loss_train: 37.97, Loss_test: 27.25
# epoch: [30] Loss_train: 35.74, Loss_test: 26.67
# epoch: [31] Loss_train: 71.24, Loss_test: 26.18
# epoch: [32] Loss_train: 15.94, Loss_test: 25.71
# epoch: [33] Loss_train: 17.51, Loss_test: 25.38
# epoch: [34] Loss_train: 50.69, Loss_test: 25.08
# epoch: [35] Loss_train: 18.26, Loss_test: 24.79
# epoch: [36] Loss_train: 17.37, Loss_test: 24.53
# epoch: [37] Loss_train: 46.41, Loss_test: 24.41
# epoch: [38] Loss_train: 26.64, Loss_test: 24.28
# epoch: [39] Loss_train: 27.32, Loss_test: 24.13
# epoch: [40] Loss_train: 11.01, Loss_test: 23.99
# epoch: [41] Loss_train: 12.82, Loss_test: 23.83
# epoch: [42] Loss_train: 13.52, Loss_test: 23.74
# epoch: [43] Loss_train: 19.89, Loss_test: 23.67
# epoch: [44] Loss_train: 22.39, Loss_test: 23.61
# epoch: [45] Loss_train: 27.42, Loss_test: 23.57
# epoch: [46] Loss_train: 37.90, Loss_test: 23.51
# epoch: [47] Loss_train: 16.47, Loss_test: 23.50
# epoch: [48] Loss_train: 21.56, Loss_test: 23.51
# epoch: [49] Loss_train: 31.59, Loss_test: 23.53
# epoch: [50] Loss_train: 36.94, Loss_test: 23.57

# %%
# epoch에 따른 loss 변화

fig, ax = plt.subplots(figsize=(7, 4))

ax.plot(range(num_epochs), train_loss, label='train')
ax.plot(range(num_epochs), test_loss, label='test')
ax.legend()

ax.set_title('Model loss', fontsize=15)
ax.set_xlabel('epoch', fontsize=12)
ax.set_ylabel('loss', fontsize=12)

plt.show()
